# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_OSA = pd.read_csv('../../../OP/MS50.Test.OSA.Coverages.txt', sep = '\t')
#df_OSA = df_OSA.rolling(window=300).sum()
df_OSB = pd.read_csv('../../../OP/MS50.Test.OSB.Coverages.txt', sep = '\t')
#df_OSB = df_OSB.rolling(window=300).sum()

df_OSA_mp = pd.read_csv('../../../OP/MS50.Test.Mispaired.OSA.Coverages.txt', sep = '\t')
#df_OSA_mp = df_OSA_mp.rolling(window=300).sum()

df_OSB_mp = pd.read_csv('../../../OP/MS50.Test.Mispaired.OSB.Coverages.txt', sep = '\t')
#df_OSB_mp = df_OSB_mp.rolling(window=300).sum()

# %%
fig,ax = plt.subplots(10,1,figsize = (16,24))
df_OSA[['Fold_Cov']].plot(ax = ax[0])
df_OSA[['Good_Cov']].plot(ax = ax[1])
df_OSA[['Orphaned_Both']].plot(ax = ax[2])
df_OSA[['Orphaned_Only']].plot(ax = ax[3])
df_OSA[['Mispaired_Both']].plot(ax = ax[4])
df_OSA[['Mispaired_Only']].plot(ax = ax[5])
df_OSA[['Partial_Both']].plot(ax = ax[6])
df_OSA[['Partial_Only']].plot(ax = ax[7])
df_OSA[['Same_Frag']].plot(ax = ax[8])
df_OSA[['Diff_Frag']].plot(ax = ax[9])
#ax[0].set_yscale('log')
#ax[0].set_ylim([1,100])

# %%
fig,ax = plt.subplots(10,1,figsize = (16,24))
df_OSB[['Fold_Cov']].plot(ax = ax[0])
df_OSB[['Good_Cov']].plot(ax = ax[1])
df_OSB[['Orphaned_Both']].plot(ax = ax[2])
df_OSB[['Orphaned_Only']].plot(ax = ax[3])
df_OSB[['Mispaired_Both']].plot(ax = ax[4])
df_OSB[['Mispaired_Only']].plot(ax = ax[5])
df_OSB[['Partial_Both']].plot(ax = ax[6])
df_OSB[['Partial_Only']].plot(ax = ax[7])
df_OSB[['Same_Frag']].plot(ax = ax[8])
df_OSB[['Diff_Frag']].plot(ax = ax[9])

# %%
fig,ax = plt.subplots(5,1,figsize = (16,12))
df_OSB_mp[['FF']].plot(ax = ax[0])
df_OSB_mp[['RR']].plot(ax = ax[1])
df_OSB_mp[['FR']].plot(ax = ax[2])
df_OSB_mp[['RF']].plot(ax = ax[3])
df_OSB[['Fold_Cov']].plot(ax = ax[4])

#ax[0].set_xlim([2170000, 2172500])
#ax[1].set_xlim([2170000, 2172500])
#ax[2].set_xlim([2170000, 2172500])
#ax[3].set_xlim([2170000, 2172500])


#fig,ax = plt.subplots(4,1,figsize = (16,10))
#df_OSB_mp[['FF']].plot(ax = ax[0])
#df_OSB_mp[['RR']].plot(ax = ax[1])
#df_OSB_mp[['FR']].plot(ax = ax[2])
#df_OSB_mp[['RF']].plot(ax = ax[3])
