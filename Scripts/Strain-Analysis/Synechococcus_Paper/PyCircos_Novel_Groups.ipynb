# %%
from PyPDF2 import PdfMerger
import pycircos
import warnings
import numpy as np
import pandas as pd
import patchworklib as pw 
import matplotlib.pyplot as plt

from os.path import isdir
from os import listdir, mkdir

warnings.filterwarnings("ignore")

rcParams = {'font.size': 20, 'font.weight': 'normal', 'font.family': 'sans-serif',
            'axes.unicode_minus':False, 'axes.labelweight':'normal'}

plt.rcParams.update(rcParams)

Garc    = pycircos.Garc
Gcircle = pycircos.Gcircle

osa_len = 2932766
osb_len = 3046682
def Make_Counts(df_osa, df_osb, samples):
    osa_indicator = {}
    osb_indicator = {}
    osa_gbl_counts = np.zeros(osa_len)
    osb_gbl_counts = np.zeros(osb_len)
    try:
        osa_samples = set(df_osa['Sample'].tolist())
    except KeyError:
        osa_samples = set({})
    try:
        osb_samples = set(df_osb['Sample'].tolist())
    except KeyError:
        osb_samples = set({})
        
    samples = osa_samples | osb_samples
    
    for g in osa_samples:
        try:
            osa = np.zeros(osa_len)
            temp_osa = df_osa[df_osa['Sample'] == g]
            starts = temp_osa['Start'].tolist()
            ends = temp_osa['End'].tolist()
            lengths = temp_osa['Length'].tolist()
            
            for i in range(len(starts)):
                start, end = int(min(starts[i],ends[i])), int(max(starts[i],ends[i]))
                if abs(start-end) == lengths[i]:    
                    osa[start:end] += 1
                    osa_gbl_counts[start:end] += 1
                else:
                    print("Here", end-start, lengths[i])
                    osa[end:osa_len] += 1
                    osa[0:start] += 1
                    osa_gbl_counts[end:osa_len] += 1
                    osa_gbl_counts[0:start] += 1
            osa[np.isnan(osa)] = 0
            osa_indicator[g] = osa
        except KeyError:
            print('OSA',g)
            osa_indicator[g] = osa
            
    for g in osb_samples:    
        try:
            osb = np.zeros(osb_len)
            temp_osb = df_osb[df_osb['Sample'] == g].reset_index()
            starts = temp_osb['Start'].tolist()
            ends = temp_osb['End'].tolist()
            lengths = temp_osb['Length'].tolist()
            
            for i in range(len(starts)):
                start, end = int(min(starts[i],ends[i])), int(max(starts[i],ends[i]))
                if abs(start-end) == lengths[i]:    
                    osb[start:end] += 1
                    osb_gbl_counts[start:end] += 1
                else:
                    print("Here", end-start, lengths[i])
                    osb[end:osa_len] += 1
                    osb[0:start] += 1
                    osb_gbl_counts[end:osb_len] += 1
                    osb_gbl_counts[0:start] += 1
            osb[np.isnan(osb)] = 0
            osb_indicator[g] = osb
        except KeyError:
            print('OSB',g)
            osb_indicator[g] = osb
    return osa_gbl_counts, osb_gbl_counts

def Max_Clique_Interval_Graph(group):
    length = group.iloc[0]['Contig_Length']
    if len(group) == 1:
        return pd.Series({'Max_Clique':1, 'Start':group['Start'].tolist()[0], 
                          'End': group['End'].tolist()[0], 'Num_Assignments': 1, 
                          'Length':length})
    
    group['Diff'] = group['Start'].shift(-1) - group['End']
    num_assign = len(group)
    max_clique = -1
    max_start, max_end = 0, 0
    clique = -1
    start, end = 0, 0
    
    difference = group['Diff'].tolist()
    starts = group['Start'].tolist()
    ends = group['End'].tolist()
    
    flag = False
    for i in range(0,len(difference)):
        if difference[i] <= 0 and flag == False:
            clique = 2
            start = starts[i]
            end = ends[i]
            flag = True
        elif difference[i] <= 0 and flag == True:
            clique += 1
        elif difference[i] > 0:
            if max_clique < clique:
                max_clique = clique
                max_start = start
                max_end = end
            flag = False
            clique = -1
    
    if max_clique < clique:
        max_clique = clique
        max_start = start
        max_end = end
            
    if max_clique == -1:
        max_clique = 1
        i = np.argmin(difference)
        max_start = starts[i]
        max_end = ends[i]
    
    return pd.Series({'Max_Clique':max_clique, 'Start':max_start, 
                      'End': max_end, 'Num_Assignments':num_assign,
                      'Length':length})
# Out:
# /Users/harihara/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
novel_contigs = {}
novel_contig_path = '/Users/harihara/Research-Activities/Data/Hot-Spring/Missing_Contig_Coords_2/'
samples = listdir(novel_contig_path+'OSA/')
for s in samples:
    df_osa = pd.read_csv(novel_contig_path+'OSA/'+s, sep = "\t")
    df_osa.loc[(df_osa['Start'] < 0), 'Start'] += osa_len
    df_osa.loc[(df_osa['End'] < 0), 'End'] += osa_len
    df_osa_grp = df_osa.sort_values(by = ['Contig','Start']).groupby(['Contig']).apply(Max_Clique_Interval_Graph)
    
    df_osb = pd.read_csv(novel_contig_path+'OSB/'+s, sep = "\t")
    df_osb.loc[(df_osb['Start'] < 0), 'Start'] += osb_len
    df_osb.loc[(df_osb['End'] < 0), 'End'] += osb_len
    df_osb_grp = df_osb.sort_values(by = ['Contig','Start']).groupby(['Contig']).apply(Max_Clique_Interval_Graph)
    
    novel_contigs[s.replace(".txt","")] = {'OSA':df_osa_grp,'OSB':df_osb_grp}

# %%
grp_path = '/Users/harihara/Research-Activities/Data/Hot-Spring/contig_containment_groups_subset_filtered.txt'
df_novel_filtered = pd.read_csv(grp_path, sep = "\t")
d = df_novel_filtered.groupby('GroupID')['Contig'].apply(list).to_dict()

out_dir = '/Users/harihara/Research-Activities/Plots/Hot_Spring_Plots/Synechococcus-Paper/Novel_Groups_Circos_2/'
if not isdir(out_dir):
    mkdir(out_dir)

# %%
i = 0
for g in list(d.keys()):
    contigs = d[g]
    osa_contig_count, osb_contig_count = 0, 0
    osa_contigs, osb_contigs = [], []
    df_osa, df_osb = pd.DataFrame(), pd.DataFrame()
    
    for c in contigs:
        splits = c.split('_')
        
        if len(splits) == 5:
            sample = splits[0]+'_'+splits[1]
            genome = splits[2].upper()
            contig = splits[3]+'_'+splits[4]
        if len(splits) == 4:
            sample = splits[0]
            genome = splits[1].upper()
            contig = splits[2]+'_'+splits[3]
        if genome == "OSA":
            osa_contig_count += 1
        if genome == "OSB":
            osb_contig_count += 1
        
        try:
            row = novel_contigs[sample][genome].loc[contig]
            row['Group'] = g
            row['Sample'] = sample
            if genome == 'OSA':
                df_osa = df_osa.append(row)
            elif genome == 'OSB':
                df_osb = df_osb.append(row)
        except:
            print("Missing...",sample,genome,contig)
            pass
    
    if len(df_osa) > 0:
        df_osa = df_osa.reset_index()
    if len(df_osb) > 0:
        df_osb = df_osb.reset_index()
    
    osa_counts, osb_counts = Make_Counts(df_osa, df_osb, list(novel_contigs.keys()))
    
    garc_osa = Garc(arc_id="OSA", interspace=0, linewidth=0, facecolor="#FFFFFF00", raxis_range=(0,10),
                    label=("Synechococcus Sub.Sp A\n"+"#Contigs (in Group):"+str(osa_contig_count)+
                           "\n#Contigs (in Graph):"+str(len(df_osa))), labelsize = 24,label_visible=True)
    garc_osb = Garc(arc_id="OSB", interspace=0, linewidth=0, facecolor="#FFFFFF00", raxis_range=(0,10),
                    label=("Synechococcus Sub.Sp B\n"+"#Contigs (in Group):"+str(osb_contig_count)+
                           "\n#Contigs (in Graph):"+str(len(df_osb))), labelsize = 24,label_visible=True)
    
    gcircle_osa = Gcircle(fig=pw.Brick._figure)
    gcircle_osa.add_garc(garc_osa)
    gcircle_osa.set_garcs()
    ylim = int(max(np.max(osa_counts), np.max(osb_counts)))+0.000001
    print(ylim)
    
    gcircle_osa.lineplot('OSA',osa_counts+0.000001,  raxis_range=(800,1000),
                         rlim = (0, ylim), linewidth = 4, linecolor = 'green')
    
    gcircle_osb = Gcircle(fig=pw.Brick._figure)
    gcircle_osb.add_garc(garc_osb)
    gcircle_osb.set_garcs()
    gcircle_osb.lineplot('OSB',osb_counts+0.000001,  raxis_range=(800,1000),
                         rlim = (0, ylim), linewidth = 4, linecolor = 'orange')
    
    pw.param["margin"] = 0.0001
    
    circos12 = pw.cBrick(ax=gcircle_osa.ax, figsize = (16,10)) | pw.cBrick(ax=gcircle_osb.ax, figsize = (16,10))
    circos12.set_suptitle(g, size = 60)
    circos12.savefig(out_dir+g+'.pdf')
    
    print(i, g)
    print(osa_contig_count, len(df_osa), np.max(osa_counts))
    print(osb_contig_count, len(df_osb), np.max(osb_counts))
    
    i+=1
    plt.close("all")
# Out:
# Missing... HotsprottomLayer OSA k141_1518
# 5.000001
# 0 Group_1003
# 9 8 5.0
# 0 0 0.0
# Missing... Hotspr2Sample148 OSB k141_11354
# 5.000001
# 1 Group_1008
# 6 6 5.0
# 9 8 4.0
# 6.000001
# 2 Group_1012
# 13 13 2.0
# 14 14 6.0
# Missing... HotsprottomLayer OSA k141_4998
# 7.000001
# 3 Group_1013
# 24 23 2.0
# 27 27 7.0
# 2.000001
# 4 Group_1015
# 12 12 2.0
# 6 6 2.0
# 3.000001
# 5 Group_1016
# 0 0 0.0
# 8 8 3.0
# 15.000001
# 6 Group_1021
# 0 0 0.0
# 25 25 15.0
# Missing... Hotspr2Sample148 OSA k141_14015
# Missing... HotsprottomLayer_2 OSA k141_9551
# Missing... HotsprSampleMS55 OSA k141_5140
# 7.000001
# 7 Group_1025
# 21 18 7.0
# 1 1 1.0
# Missing... Hotspr2Sample148 OSB k141_32465
# Missing... Hotspr2Sampleee2 OSB k141_1426
# Missing... Hotspr2Sampleme2 OSB k141_74679
# Missing... Hotspr2SamplePe2 OSB k141_544
# Missing... HotsprSampleMS60 OSB k141_23227
# 1.000001
# 8 Group_1030
# 1 1 1.0
# 5 0 0.0
# Missing... Hotspr20SampleT8 OSB k141_28821
# Missing... Hotspr2Sample148 OSA k141_13686
# Missing... Hotspr2Sample148 OSB k141_27481
# Missing... Hotspr2Sample149 OSA k141_13694
# Missing... Hotspr2Sample149 OSB k141_20261
# Missing... HotsprOSTMatCore OSB k141_6606
# Missing... HotsprottomLayer_2 OSA k141_66
# Missing... HotsprottomLayer_2 OSB k141_4447
# Missing... HotsprottomLayer OSA k141_875
# Missing... HotsprottomLayer OSB k141_14728
# Missing... HotsprSampleMS13 OSA k141_16058
# Missing... HotsprSampleMS13 OSB k141_61321
# Missing... HotsprSampleMS50 OSA k141_24258
# Missing... HotsprSampleMS55 OSB k141_4906
# Missing... HotsprSampleMSe1 OSA k141_19945
# Missing... HotsprSampleMSe1 OSB k141_10509
# Missing... HotsprSampleMSe2 OSA k141_3212
# Missing... HotsprSampleMSe2 OSB k141_88825
# Missing... HotsprSampleMSe4 OSA k141_23158
# Missing... HotsprSampleMSe4 OSB k141_66887
# Missing... HotsprSampleOS65 OSA k141_14501
# Missing... HotsprSampleOS65 OSB k141_36880
# Missing... HotsprSampleR4cd OSA k141_4070
# Missing... HotsprSamplt10cd OSB k141_56712
# 1.000001
# 9 Group_1034
# 12 1 1.0
# 15 2 1.0
# 2.000001
# 10 Group_1040
# 6 6 2.0
# 2 2 1.0
# Missing... Hotspr2Sample148 OSB k141_13890
# Missing... HotsprSampleMSe3 OSB k141_6484
# Missing... HotsprSampleOSM3 OSB k141_23543
# 8.000001
# 11 Group_1042
# 0 0 0.0
# 16 13 8.0
# Missing... Hotspr2Sample149 OSA k141_13
# Missing... HotsprottomLayer OSB k141_15178
# Missing... HotsprSampleMS50 OSA k141_3055
# Missing... HotsprSampleMS55 OSB k141_21057
# Missing... HotsprSampleMS65 OSB k141_11788
# Missing... HotsprSampleOS50 OSA k141_7346
# Missing... HotsprSampleOSM1 OSA k141_10241
# Missing... HotsprSampleOSM3 OSB k141_29905
# Missing... HotsprSampOS1260 OSB k141_9771
# 8.000001
# 12 Group_1044
# 14 10 4.0
# 20 15 8.0
# Missing... HotsprSampleOSM2 OSB k141_4772
# 13.000001
# 13 Group_105
# 37 37 6.0
# 46 45 13.0
# Missing... HotsprSampleMSe4 OSA k141_31059
# 1.000001
# 14 Group_1051
# 6 5 1.0
# 2 2 1.0
# Missing... Hotspr2Sampleee2 OSA k141_21928
# 2.000001
# 15 Group_1058
# 19 18 2.0
# 1 1 1.0
# Missing... HotsprSampleMS55 OSA k141_13016
# 6.000001
# 16 Group_1066
# 20 19 6.0
# 12 12 4.0
# Missing... Hotspr20SampleP4 OSA k141_23238
# Missing... Hotspr20SampleP4 OSB k141_62236
# Missing... Hotspr20SampleT8 OSA k141_19584
# Missing... Hotspr20SampleT9 OSB k141_11461
# Missing... Hotspr2Sampleee2 OSA k141_29397
# Missing... Hotspr2Sampleee2 OSB k141_58708
# Missing... Hotspr2Sampleme2 OSB k141_37370
# Missing... HotsprSampleMSe2 OSA k141_3697
# Missing... HotsprSampleMSe2 OSB k141_62366
# Missing... HotsprSampleMSe4 OSB k141_6439
# Missing... HotsprSampleR4cd OSB k141_1758
# 1.000001
# 17 Group_1075
# 5 1 1.0
# 8 1 1.0
# Missing... Hotspr20SampleP4 OSA k141_10273
# Missing... Hotspr20Samplet1 OSB k141_19254
# Missing... Hotspr2Sample148 OSA k141_2765
# Missing... Hotspr2Sampleme2 OSA k141_3104
# Missing... Hotspr2SamplePe2 OSA k141_5598
# Missing... HotsprSampleOS50 OSB k141_24085
# Missing... HotsprSampleOSM3 OSA k141_1181
# Missing... HotsprSamplt10cd OSA k141_5397
# Missing... HotsprSampOS1260 OSB k141_5140
# 5.000001
# 18 Group_1079
# 17 11 5.0
# 16 13 4.0
# 2.000001
# 19 Group_1098
# 2 2 1.0
# 7 7 2.0
# Missing... Hotspr2Sampleme2 OSA k141_13942
# Missing... HotsprSampleOSM2 OSB k141_11949
# Missing... HotsprSampleOSM3 OSB k141_25576
# Missing... HotsprSampOS1260 OSB k141_14433
# 5.000001
# 20 Group_1106
# 1 0 0.0
# 10 7 5.0
# Missing... Hotspr20SampleP4 OSB k141_20379
# Missing... Hotspr20SampleT8 OSB k141_61603
# Missing... Hotspr2Sampleee2 OSB k141_48106
# Missing... Hotspr2Sampleme2 OSB k141_52786
# Missing... Hotspr2SamplePe2 OSB k141_35974
# Missing... HotsprSampleMS13 OSB k141_22529
# Missing... HotsprSampleMS60 OSB k141_25181
# Missing... HotsprSampleMSe3 OSB k141_34175
# Missing... HotsprSampleOSM2 OSB k141_2113
# Missing... HotsprSampleOSM4 OSB k141_46965
# Missing... HotsprSamplt10cd OSB k141_69101
# Missing... HotsprSampOS1265 OSB k141_9310
# 1.000001
# 21 Group_1153
# 0 0 0.0
# 13 1 1.0
# Missing... HotsprottomLayer OSA k141_1680
# Missing... HotsprottomLayer OSB k141_10753
# 3.000001
# 22 Group_1156
# 15 14 3.0
# 5 4 2.0
# 4.000001
# 23 Group_1174
# 8 8 4.0
# 1 1 1.0
# Missing... HotsprSampleMS13 OSA k141_16511
# Missing... HotsprSampleMS60 OSA k141_8800
# Missing... HotsprSampleOSM1 OSA k141_5727
# Missing... HotsprSampOS1260 OSA k141_13607
# 2.000001
# 24 Group_1178
# 6 2 2.0
# 0 0 0.0
# 4.000001
# 25 Group_1184
# 7 7 4.0
# 6 6 3.0
# 4.000001
# 26 Group_1189
# 9 9 4.0
# 3 3 2.0
# Missing... Hotspr2Sample149 OSA k141_2070
# Missing... Hotspr2Sampleme2 OSA k141_12584
# Missing... HotsprOSTMatCore OSA k141_1931
# Missing... HotsprSampleMS50 OSA k141_12654
# Missing... HotsprSampleMS55 OSA k141_3935
# Missing... HotsprSampleMS55 OSB k141_27568
# Missing... HotsprSampleMS60 OSA k141_2690
# Missing... HotsprSampleMS65 OSA k141_10578
# Missing... HotsprSampleMSe3 OSA k141_13335
# Missing... HotsprSampleOS50 OSA k141_3240
# Missing... HotsprSampleOS55 OSB k141_2357
# Missing... HotsprSampleOS65 OSA k141_3552
# Missing... HotsprSampleOSM2 OSB k141_8535
# Missing... HotsprSampOS1260 OSB k141_1101
# 11.000001
# 27 Group_125
# 38 28 9.0
# 23 19 11.0
# 11.000001
# 28 Group_128
# 0 0 0.0
# 32 32 11.0
# Missing... Hotspr20Samplem2 OSB k141_27200
# Missing... Hotspr20Samplet1 OSA k141_20787
# Missing... Hotspr20Samplet1 OSB k141_12384
# Missing... HotsprSampleMS60 OSB k141_38436
# Missing... HotsprSampleOS55 OSB k141_12333
# Missing... HotsprSampleOSM1 OSB k141_4059
# Missing... HotsprSampleOSM3 OSB k141_10664
# Missing... HotsprSamplt10cd OSB k141_60226
# Missing... HotsprSampOS1265 OSA k141_9215
# 2.000001
# 29 Group_130
# 4 2 2.0
# 10 3 1.0
# Missing... Hotspr20Samplem2 OSB k141_4669
# Missing... Hotspr20Samplet1 OSA k141_18847
# Missing... Hotspr20Samplet1 OSB k141_925
# Missing... HotsprSampleMS65 OSB k141_12053
# Missing... HotsprSampleMS65 OSB k141_3881
# Missing... HotsprSampleOS55 OSB k141_4229
# Missing... HotsprSampleOSM1 OSA k141_4158
# Missing... HotsprSamplt10cd OSA k141_2901
# Missing... HotsprSampOS1260 OSA k141_13004
# Missing... HotsprSampOS1260 OSB k141_11530
# Missing... HotsprSampOS1265 OSA k141_13855
# Missing... HotsprSampOS1265 OSB k141_3018
# 1.000001
# 30 Group_175
# 8 3 1.0
# 7 0 0.0
# Missing... Hotspr2Sampleee2 OSA k141_14618
# Missing... Hotspr2SamplePe2 OSA k141_19930
# Missing... HotsprottomLayer OSA k141_1816
# Missing... HotsprSampleOS50 OSB k141_30827
# Missing... HotsprSampleOS65 OSA k141_416
# Missing... HotsprSampleR4cd OSA k141_986
# 6.000001
# 31 Group_179
# 21 16 6.0
# 15 14 6.0
# Missing... Hotspr20Samplem2 OSA k141_14859
# Missing... Hotspr20Samplem2 OSB k141_18875
# Missing... HotsprSampleMS13 OSB k141_7110
# Missing... HotsprSampleOS55 OSB k141_2243
# Missing... HotsprSampleOSM3 OSA k141_11726
# Missing... HotsprSampOS1265 OSA k141_2085
# Missing... HotsprSampOS1265 OSB k141_9347
# 3.000001
# 32 Group_180
# 7 4 3.0
# 5 1 1.0
# Missing... Hotspr2Sampleee2 OSA k141_34116
# Missing... Hotspr2SamplePe2 OSA k141_15704
# Missing... Hotspr2SamplePe2 OSB k141_48088
# Missing... HotsprottomLayer_2 OSA k141_14
# Missing... HotsprSampleMS13 OSA k141_20785
# Missing... HotsprSampleMS60 OSA k141_11331
# Missing... HotsprSampleMSe4 OSA k141_18491
# Missing... HotsprSampleOSM2 OSB k141_10181
# 9.000001
# 33 Group_182
# 19 13 9.0
# 20 18 6.0
# Missing... Hotspr20Samplem2 OSB k141_11975
# Missing... Hotspr20SampleP4 OSB k141_57163
# Missing... Hotspr20Samplet1 OSB k141_5447
# Missing... Hotspr20Samplet1 OSB k141_8277
# Missing... Hotspr20SampleT8 OSB k141_23729
# Missing... Hotspr2Sample148 OSB k141_33732
# Missing... Hotspr2Sample149 OSB k141_28201
# Missing... Hotspr2SamplePe2 OSB k141_48795
# Missing... HotsprottomLayer OSB k141_471
# Missing... HotsprSampleMS13 OSB k141_4120
# Missing... HotsprSampleMS65 OSB k141_13003
# Missing... HotsprSampleMSe1 OSB k141_40689
# Missing... HotsprSampleMSe4 OSB k141_75364
# Missing... HotsprSampleOS55 OSB k141_8935
# Missing... HotsprSampleOSM1 OSB k141_9038
# Missing... HotsprSampleOSM4 OSB k141_36461
# Missing... HotsprSampleOSM4 OSB k141_39078
# Missing... HotsprSampOS1265 OSB k141_7365
# 1.000001
# 34 Group_187
# 0 0 0.0
# 19 1 1.0
# Missing... Hotspr20Samplem2 OSA k141_766
# Missing... HotsprottomLayer_2 OSA k141_1936
# Missing... HotsprottomLayer_2 OSA k141_2626
# Missing... HotsprSampOS1260 OSA k141_11097
# 4.000001
# 35 Group_211
# 25 21 4.0
# 6 6 2.0
# Missing... Hotspr2SamplePe2 OSB k141_215
# Missing... HotsprSampleR4cd OSB k141_31309
# 10.000001
# 36 Group_218
# 23 23 8.0
# 20 18 10.0
# Missing... Hotspr20Samplem2 OSB k141_17753
# Missing... HotsprSampleMS13 OSB k141_26733
# Missing... HotsprSampleMS55 OSB k141_25740
# 15.000001
# 37 Group_223
# 0 0 0.0
# 31 28 15.0
# Missing... Hotspr2Sample148 OSB k141_11393
# Missing... Hotspr2SamplePe2 OSB k141_25784
# Missing... HotsprSampleMS55 OSB k141_25439
# Missing... HotsprSampleMSe2 OSB k141_53556
# Missing... HotsprSampleOSM2 OSB k141_8528
# Missing... HotsprSampleR4cd OSA k141_39201
# 13.000001
# 38 Group_23
# 22 21 11.0
# 22 17 13.0
# Missing... Hotspr20Samplem2 OSB k141_13432
# Missing... Hotspr20Samplet1 OSB k141_6315
# Missing... Hotspr2Sample149 OSB k141_8857
# Missing... Hotspr2Sampleee2 OSA k141_26311
# Missing... HotsprSampleMS55 OSB k141_27956
# Missing... HotsprSampleMS60 OSB k141_32904
# Missing... HotsprSampleMSe3 OSA k141_1160
# Missing... HotsprSampleOS50 OSB k141_13199
# Missing... HotsprSampleOSM2 OSB k141_15213
# Missing... HotsprSampleOSM3 OSB k141_39066
# 25.000001
# 39 Group_249
# 3 1 1.0
# 53 45 25.0
# Missing... HotsprSampleMS55 OSB k141_39931
# Missing... HotsprSampOS1260 OSB k141_6879
# 5.000001
# 40 Group_258
# 0 0 0.0
# 13 11 5.0
# Missing... Hotspr20SampleT8 OSA k141_26211
# Missing... HotsprottomLayer_2 OSA k141_7170
# Missing... HotsprSampleOS65 OSA k141_8410
# 13.000001
# 41 Group_284
# 41 38 13.0
# 4 4 2.0
# Missing... HotsprottomLayer_2 OSA k141_9243
# Missing... HotsprottomLayer OSA k141_1919
# 7.000001
# 42 Group_286
# 19 17 2.0
# 13 13 7.0
# Missing... Hotspr20Samplem2 OSB k141_12082
# Missing... Hotspr20Samplet1 OSA k141_4039
# Missing... HotsprSampleMS13 OSA k141_3618
# Missing... HotsprSampleMS65 OSB k141_5672
# Missing... HotsprSampleOSM1 OSA k141_16923
# Missing... HotsprSampleOSM2 OSA k141_3571
# Missing... HotsprSamplt10cd OSA k141_18106
# Missing... HotsprSampOS1265 OSA k141_9324
# 3.000001
# 43 Group_290
# 9 3 3.0
# 2 0 0.0
# Missing... Hotspr20Samplem2 OSA k141_18855
# Missing... Hotspr20SampleP4 OSA k141_16568
# Missing... Hotspr20Samplet1 OSA k141_18643
# Missing... Hotspr20SampleT8 OSA k141_24560
# Missing... Hotspr20SampleT9 OSA k141_4317
# Missing... Hotspr2Sampleee2 OSA k141_2922
# Missing... Hotspr2Sampleme2 OSA k141_7050
# Missing... Hotspr2SamplePe2 OSA k141_1464
# Missing... HotsprSampleMS13 OSA k141_7869
# Missing... HotsprSampleMS60 OSA k141_4967
# Missing... HotsprSampleMSe1 OSA k141_10377
# Missing... HotsprSampleMSe2 OSA k141_4416
# Missing... HotsprSampleMSe3 OSA k141_10061
# Missing... HotsprSampleOSM2 OSA k141_12731
# Missing... HotsprSampleOSM3 OSA k141_21485
# Missing... HotsprSampleOSM4 OSA k141_6297
# Missing... HotsprSamplt10cd OSA k141_23465
# 4.000001
# 44 Group_306
# 22 5 4.0
# 0 0 0.0
# Missing... Hotspr20SampleT9 OSA k141_13683
# Missing... Hotspr20SampleT9 OSA k141_5031
# Missing... Hotspr20SampleT9 OSB k141_8874
# Missing... Hotspr2Sample148 OSB k141_1967
# Missing... Hotspr2Sample149 OSA k141_12647
# Missing... Hotspr2Sample149 OSB k141_19750
# Missing... Hotspr2Sampleee2 OSA k141_13832
# Missing... Hotspr2Sampleee2 OSB k141_37243
# Missing... Hotspr2Sampleee2 OSB k141_44140
# Missing... Hotspr2Sampleme2 OSA k141_10797
# Missing... Hotspr2Sampleme2 OSB k141_6751
# Missing... HotsprSampleMS50 OSB k141_50314
# Missing... HotsprSampleMS55 OSB k141_11622
# Missing... HotsprSampleMS60 OSB k141_34084
# Missing... HotsprSampleMSe1 OSB k141_50893
# Missing... HotsprSampleMSe2 OSB k141_67974
# Missing... HotsprSampleMSe3 OSB k141_16045
# Missing... HotsprSampleOS60 OSA k141_7596
# Missing... HotsprSampleOS60 OSB k141_9993
# Missing... HotsprSampleOS65 OSB k141_35432
# Missing... HotsprSampleOSM1 OSA k141_16931
# Missing... HotsprSampleOSM2 OSA k141_4415
# Missing... HotsprSampleOSM3 OSA k141_4329
# Missing... HotsprSampleR4cd OSA k141_37788
# Missing... HotsprSampleR4cd OSB k141_34983
# Missing... HotsprSamplt10cd OSB k141_21750
# Missing... HotsprSamplt10cd OSB k141_72840
# Missing... HotsprSampOS1260 OSA k141_13690
# Missing... HotsprSampOS1265 OSA k141_12168
# 9.000001
# 45 Group_312
# 28 16 9.0
# 32 15 9.0
# Missing... Hotspr20Samplet1 OSA k141_8362
# Missing... Hotspr20SampleT9 OSB k141_40346
# Missing... HotsprSampleMS55 OSA k141_11493
# Missing... HotsprSampleMSe2 OSA k141_27318
# Missing... HotsprSampleMSe3 OSA k141_5202
# Missing... HotsprSampleOSM1 OSB k141_2824
# Missing... HotsprSampleOSM4 OSB k141_58709
# 7.000001
# 46 Group_321
# 21 17 7.0
# 10 7 5.0
# Missing... Hotspr20Samplem2 OSA k141_16843
# 3.000001
# 47 Group_322
# 12 11 3.0
# 6 6 2.0
# Missing... HotsprSampleOS50 OSB k141_32195
# Missing... HotsprSampleOS65 OSA k141_13300
# Missing... HotsprSampleOSM2 OSA k141_1719
# Missing... HotsprSampOS1260 OSA k141_14025
# 6.000001
# 48 Group_323
# 18 15 5.0
# 19 18 6.0
# Missing... HotsprSampleMS13 OSA k141_16569
# Missing... HotsprSamplt10cd OSA k141_26739
# 10.000001
# 49 Group_333
# 17 15 10.0
# 0 0 0.0
# Missing... Hotspr20SampleP4 OSB k141_39509
# Missing... Hotspr2SamplePe2 OSB k141_47072
# Missing... HotsprottomLayer OSA k141_1083
# Missing... HotsprottomLayer OSB k141_14643
# Missing... HotsprSampleMS60 OSB k141_3000
# Missing... HotsprSampleMSe2 OSA k141_8784
# Missing... HotsprSampleMSe2 OSB k141_33949
# Missing... HotsprSampleOSM4 OSB k141_68246
# 3.000001
# 50 Group_335
# 9 7 3.0
# 10 4 3.0
# Missing... Hotspr20Samplem2 OSB k141_9548
# Missing... Hotspr20SampleT8 OSB k141_19608
# Missing... Hotspr20SampleT8 OSB k141_3638
# Missing... Hotspr2Sample148 OSB k141_29346
# Missing... Hotspr2Sample149 OSB k141_18173
# Missing... Hotspr2Sampleme2 OSB k141_20366
# Missing... Hotspr2Sampleme2 OSB k141_28320
# Missing... HotsprSampleMS60 OSB k141_14560
# Missing... HotsprSampleMSe1 OSB k141_35124
# Missing... HotsprSampleOS60 OSB k141_3764
# Missing... HotsprSampleOSM1 OSB k141_753
# 20.000001
# 51 Group_353
# 0 0 0.0
# 44 33 20.0
# Missing... Hotspr20Samplem2 OSA k141_120
# Missing... Hotspr2Sample148 OSA k141_5076
# Missing... Hotspr2Sample149 OSA k141_12841
# Missing... Hotspr2Sampleme2 OSA k141_19839
# Missing... HotsprOSTMatCore OSB k141_4705
# Missing... HotsprottomLayer OSA k141_1921
# Missing... HotsprSampleMS50 OSA k141_18481
# 7.000001
# 52 Group_364
# 28 22 4.0
# 52 51 7.0
# Missing... Hotspr20Samplem2 OSA k141_15443
# Missing... Hotspr20SampleP4 OSA k141_11485
# Missing... Hotspr20SampleP4 OSA k141_3823
# Missing... Hotspr20SampleP4 OSB k141_36609
# Missing... Hotspr20Samplet1 OSA k141_10705
# Missing... Hotspr20Samplet1 OSB k141_477
# Missing... Hotspr20SampleT8 OSA k141_18232
# Missing... Hotspr20SampleT8 OSA k141_4398
# Missing... Hotspr20SampleT8 OSB k141_37369
# Missing... Hotspr20SampleT9 OSA k141_15377
# Missing... Hotspr20SampleT9 OSA k141_3986
# Missing... Hotspr20SampleT9 OSB k141_29540
# Missing... Hotspr2Sample148 OSB k141_31795
# Missing... Hotspr2Sample149 OSA k141_13388
# Missing... Hotspr2Sample149 OSB k141_18455
# Missing... Hotspr2Sampleee2 OSA k141_6377
# Missing... Hotspr2Sampleee2 OSA k141_7896
# Missing... Hotspr2Sampleee2 OSB k141_17468
# Missing... Hotspr2Sampleee2 OSB k141_27849
# Missing... Hotspr2Sampleme2 OSA k141_19314
# Missing... Hotspr2Sampleme2 OSB k141_30570
# Missing... Hotspr2Sampleme2 OSB k141_71822
# Missing... Hotspr2SamplePe2 OSA k141_11478
# Missing... Hotspr2SamplePe2 OSB k141_6948
# Missing... HotsprOSTMatCore OSA k141_766
# Missing... HotsprOSTMatCore OSB k141_8479
# Missing... HotsprottomLayer OSA k141_739
# Missing... HotsprottomLayer OSB k141_1980
# Missing... HotsprSampleMS13 OSA k141_14079
# Missing... HotsprSampleMS13 OSA k141_18626
# Missing... HotsprSampleMS13 OSB k141_35112
# Missing... HotsprSampleMS13 OSB k141_63501
# Missing... HotsprSampleMS50 OSA k141_13364
# Missing... HotsprSampleMS50 OSB k141_39119
# Missing... HotsprSampleMS50 OSB k141_48269
# Missing... HotsprSampleMS55 OSA k141_14075
# Missing... HotsprSampleMS55 OSA k141_14452
# Missing... HotsprSampleMS55 OSB k141_40052
# Missing... HotsprSampleMS60 OSA k141_13081
# Missing... HotsprSampleMS60 OSA k141_5014
# Missing... HotsprSampleMS60 OSB k141_32748
# Missing... HotsprSampleMS65 OSA k141_22631
# Missing... HotsprSampleMS65 OSB k141_3350
# Missing... HotsprSampleMSe1 OSA k141_26708
# Missing... HotsprSampleMSe1 OSA k141_8878
# Missing... HotsprSampleMSe1 OSB k141_1956
# Missing... HotsprSampleMSe2 OSA k141_23473
# Missing... HotsprSampleMSe2 OSA k141_25982
# Missing... HotsprSampleMSe2 OSB k141_81625
# Missing... HotsprSampleMSe3 OSA k141_11313
# Missing... HotsprSampleMSe3 OSA k141_12250
# Missing... HotsprSampleMSe3 OSB k141_31269
# Missing... HotsprSampleMSe3 OSB k141_42335
# Missing... HotsprSampleMSe4 OSA k141_21418
# Missing... HotsprSampleMSe4 OSA k141_8733
# Missing... HotsprSampleMSe4 OSB k141_29142
# Missing... HotsprSampleMSe4 OSB k141_45835
# Missing... HotsprSampleOS55 OSA k141_17334
# Missing... HotsprSampleOS55 OSB k141_9184
# Missing... HotsprSampleOS60 OSA k141_7913
# Missing... HotsprSampleOS60 OSB k141_1158
# Missing... HotsprSampleOS65 OSB k141_6501
# Missing... HotsprSampleOSM1 OSA k141_6652
# Missing... HotsprSampleOSM1 OSB k141_3756
# Missing... HotsprSampleOSM2 OSA k141_6789
# Missing... HotsprSampleOSM2 OSA k141_8190
# Missing... HotsprSampleOSM2 OSB k141_14018
# Missing... HotsprSampleOSM2 OSB k141_6657
# Missing... HotsprSampleOSM3 OSA k141_1428
# Missing... HotsprSampleOSM3 OSA k141_4526
# Missing... HotsprSampleOSM3 OSB k141_1612
# Missing... HotsprSampleOSM4 OSA k141_15419
# Missing... HotsprSampleOSM4 OSB k141_14763
# Missing... HotsprSampleR4cd OSA k141_24121
# Missing... HotsprSampleR4cd OSB k141_108789
# Missing... HotsprSamplt10cd OSA k141_15616
# Missing... HotsprSamplt10cd OSA k141_6549
# Missing... HotsprSamplt10cd OSB k141_14472
# Missing... HotsprSamplt10cd OSB k141_69611
# Missing... HotsprSampOS1260 OSA k141_10809
# Missing... HotsprSampOS1260 OSB k141_17805
# Missing... HotsprSampOS1265 OSA k141_4437
# Missing... HotsprSampOS1265 OSB k141_10839
# 3.000001
# 53 Group_365
# 47 3 2.0
# 44 5 3.0
# Missing... Hotspr20SampleT8 OSA k141_1164
# Missing... Hotspr20SampleT8 OSA k141_27387
# Missing... Hotspr20SampleT9 OSA k141_15092
# Missing... Hotspr2Sample148 OSA k141_4703
# Missing... Hotspr2Sampleee2 OSA k141_23429
# Missing... Hotspr2Sampleme2 OSA k141_7998
# Missing... Hotspr2SamplePe2 OSA k141_6679
# Missing... HotsprSampleMS13 OSA k141_1960
# Missing... HotsprSampleMS50 OSA k141_783
# Missing... HotsprSampleMS55 OSA k141_11405
# Missing... HotsprSampleMS60 OSA k141_16190
# Missing... HotsprSampleMSe1 OSA k141_17111
# Missing... HotsprSampleMSe2 OSA k141_13662
# Missing... HotsprSampleMSe2 OSA k141_15508
# Missing... HotsprSampleMSe3 OSA k141_17073
# Missing... HotsprSampleMSe3 OSA k141_17533
# Missing... HotsprSampleMSe4 OSA k141_14925
# Missing... HotsprSampleOS65 OSA k141_1215
# Missing... HotsprSampleOSM3 OSA k141_25617
# Missing... HotsprSampleOSM4 OSA k141_22485
# Missing... HotsprSampleR4cd OSA k141_14412
# Missing... HotsprSampleR4cd OSA k141_22624
# Missing... HotsprSamplt10cd OSA k141_272
# 1.000001
# 54 Group_382
# 24 1 1.0
# 0 0 0.0
# Missing... Hotspr2Sample148 OSB k141_26626
# Missing... Hotspr2Sample149 OSB k141_22297
# Missing... HotsprottomLayer OSB k141_337
# Missing... HotsprSampleMS55 OSB k141_42536
# Missing... HotsprSampleR4cd OSB k141_105403
# 10.000001
# 55 Group_40
# 20 20 7.0
# 20 15 10.0
# Missing... Hotspr20SampleT8 OSA k141_21412
# Missing... Hotspr20SampleT9 OSA k141_14155
# Missing... HotsprSampleMSe1 OSA k141_19696
# Missing... HotsprSampleMSe2 OSA k141_25909
# 15.000001
# 56 Group_406
# 6 2 1.0
# 25 25 15.0
# Missing... Hotspr20SampleP4 OSA k141_20385
# Missing... Hotspr20SampleT8 OSA k141_16812
# Missing... Hotspr20SampleT9 OSA k141_21076
# Missing... Hotspr2Sampleee2 OSA k141_31682
# Missing... Hotspr2Sampleme2 OSA k141_26126
# Missing... Hotspr2SamplePe2 OSA k141_20811
# Missing... HotsprSampleMS13 OSA k141_15483
# Missing... HotsprSampleMS50 OSA k141_4444
# Missing... HotsprSampleMS60 OSA k141_16103
# Missing... HotsprSampleMSe1 OSA k141_12453
# Missing... HotsprSampleMSe2 OSA k141_25873
# Missing... HotsprSampleMSe3 OSA k141_21779
# Missing... HotsprSampleMSe3 OSA k141_6049
# Missing... HotsprSampleMSe4 OSA k141_22483
# Missing... HotsprSampleOSM3 OSA k141_14044
# Missing... HotsprSampleR4cd OSA k141_8984
# 1e-06
# 57 Group_416
# 16 0 0.0
# 0 0 0.0
# Missing... Hotspr20SampleT9 OSA k141_17961
# Missing... Hotspr2Sample149 OSA k141_13840
# Missing... HotsprSampleMSe4 OSA k141_23283
# 8.000001
# 58 Group_419
# 13 10 8.0
# 0 0 0.0
# Missing... HotsprOSTMatCore OSA k141_4059
# Missing... HotsprottomLayer_2 OSA k141_989
# Missing... HotsprSampleMS55 OSA k141_18451
# Missing... HotsprSampleOSM2 OSA k141_7697
# Missing... HotsprSampOS1260 OSA k141_4301
# 6.000001
# 59 Group_423
# 26 21 6.0
# 16 16 4.0
# 2.000001
# 60 Group_437
# 2 2 1.0
# 9 9 2.0
# 5.000001
# 61 Group_464
# 15 15 5.0
# 3 3 1.0
# Missing... Hotspr20Samplem2 OSB k141_16723
# Missing... HotsprSampleMS60 OSA k141_9591
# Missing... HotsprSampleOS55 OSB k141_5579
# Missing... HotsprSampleOSM3 OSA k141_15368
# Missing... HotsprSampleOSM3 OSA k141_17084
# 10.000001
# 62 Group_476
# 13 10 7.0
# 19 17 10.0
# Missing... HotsprSampleMSe2 OSB k141_44116
# Missing... HotsprSampleOSM2 OSB k141_7226
# 7.000001
# 63 Group_482
# 0 0 0.0
# 15 13 7.0
# Missing... Hotspr2SamplePe2 OSB k141_9677
# 17.000001
# 64 Group_485
# 19 19 11.0
# 28 27 17.0
# 2.000001
# 65 Group_495
# 10 10 2.0
# 3 3 2.0
# Missing... Hotspr20Samplem2 OSA k141_1429
# Missing... Hotspr20SampleT8 OSA k141_5145
# Missing... Hotspr2Sample149 OSA k141_4437
# Missing... Hotspr2Sampleme2 OSA k141_23125
# Missing... HotsprSampleMS13 OSA k141_25304
# Missing... HotsprSampOS1265 OSA k141_5135
# 14.000001
# 66 Group_498
# 31 25 14.0
# 17 17 9.0
# Missing... HotsprottomLayer_2 OSA k141_4129
# Missing... HotsprSampleMS13 OSB k141_65526
# Missing... HotsprSampleMS55 OSA k141_568
# Missing... HotsprSampleOS50 OSB k141_5734
# 20.000001
# 67 Group_501
# 27 25 20.0
# 26 24 12.0
# Missing... HotsprSampOS1260 OSA k141_21381
# 3.000001
# 68 Group_508
# 17 16 1.0
# 13 13 3.0
# Missing... Hotspr20SampleT9 OSA k141_2127
# Missing... Hotspr2Sample148 OSA k141_3563
# Missing... HotsprSampleMS60 OSA k141_17385
# Missing... HotsprSampleMSe2 OSA k141_19877
# 17.000001
# 69 Group_519
# 13 9 9.0
# 28 28 17.0
# Missing... HotsprSampleMSe2 OSB k141_90602
# 7.000001
# 70 Group_521
# 17 17 5.0
# 18 17 7.0
# Missing... Hotspr2Sample148 OSA k141_12035
# Missing... HotsprSampleMS55 OSA k141_15870
# 6.000001
# 71 Group_525
# 19 17 6.0
# 13 13 4.0
# Missing... HotsprottomLayer OSA k141_5420
# Missing... HotsprSampleOSM4 OSA k141_7498
# 5.000001
# 72 Group_538
# 20 18 5.0
# 7 7 3.0
# Missing... Hotspr20SampleT9 OSA k141_2430
# Missing... Hotspr2Sample148 OSA k141_10043
# Missing... Hotspr2Sampleee2 OSA k141_20556
# Missing... Hotspr2Sampleme2 OSA k141_8643
# Missing... Hotspr2SamplePe2 OSA k141_152
# Missing... Hotspr2SamplePe2 OSA k141_17760
# Missing... HotsprOSTMatCore OSA k141_2272
# Missing... HotsprottomLayer OSA k141_2290
# Missing... HotsprSampleMS13 OSA k141_4362
# Missing... HotsprSampleMSe1 OSA k141_3951
# Missing... HotsprSampleMSe2 OSA k141_14235
# Missing... HotsprSampleMSe2 OSA k141_6485
# Missing... HotsprSampleMSe3 OSA k141_7315
# Missing... HotsprSampleMSe4 OSA k141_18693
# Missing... HotsprSampleR4cd OSA k141_35955
# 3.000001
# 73 Group_577
# 19 4 3.0
# 0 0 0.0
# 3.000001
# 74 Group_585
# 10 10 3.0
# 2 2 1.0
# Missing... Hotspr20Samplem2 OSA k141_18286
# Missing... Hotspr20Samplem2 OSB k141_2440
# Missing... Hotspr20SampleP4 OSA k141_12049
# Missing... Hotspr20SampleP4 OSB k141_12183
# Missing... Hotspr20SampleT8 OSA k141_9499
# Missing... Hotspr20SampleT8 OSB k141_56550
# Missing... Hotspr20SampleT9 OSA k141_23702
# Missing... Hotspr20SampleT9 OSB k141_63824
# Missing... Hotspr2Sampleee2 OSA k141_22535
# Missing... Hotspr2Sampleee2 OSB k141_65007
# Missing... Hotspr2Sampleme2 OSA k141_22206
# Missing... Hotspr2Sampleme2 OSB k141_58430
# Missing... Hotspr2SamplePe2 OSA k141_6109
# Missing... Hotspr2SamplePe2 OSB k141_11697
# Missing... HotsprottomLayer_2 OSA k141_3081
# Missing... HotsprottomLayer_2 OSB k141_15787
# Missing... HotsprSampleMS13 OSB k141_43257
# Missing... HotsprSampleMS60 OSA k141_2253
# Missing... HotsprSampleMS60 OSB k141_26914
# Missing... HotsprSampleMSe1 OSA k141_16365
# Missing... HotsprSampleMSe1 OSB k141_20409
# Missing... HotsprSampleMSe2 OSB k141_13518
# Missing... HotsprSampleMSe3 OSA k141_7070
# Missing... HotsprSampleMSe3 OSB k141_53345
# Missing... HotsprSampleMSe4 OSA k141_31828
# Missing... HotsprSampleMSe4 OSB k141_32976
# Missing... HotsprSampleOS50 OSA k141_12213
# Missing... HotsprSampleOS50 OSB k141_22670
# Missing... HotsprSampleOS65 OSB k141_1622
# Missing... HotsprSampleOSM2 OSA k141_8305
# Missing... HotsprSampleOSM2 OSB k141_2543
# Missing... HotsprSampleOSM3 OSA k141_23293
# Missing... HotsprSampleOSM3 OSB k141_32803
# Missing... HotsprSampleOSM4 OSA k141_7215
# Missing... HotsprSampleOSM4 OSB k141_3434
# Missing... HotsprSamplt10cd OSA k141_16671
# Missing... HotsprSamplt10cd OSB k141_59497
# Missing... HotsprSampOS1260 OSA k141_8621
# Missing... HotsprSampOS1265 OSA k141_13235
# Missing... HotsprSampOS1265 OSB k141_4237
# 1.000001
# 75 Group_590
# 20 1 1.0
# 21 0 0.0
# Missing... Hotspr20SampleT8 OSB k141_39249
# Missing... HotsprSampleMS13 OSB k141_10915
# Missing... HotsprSampleMS60 OSB k141_14861
# Missing... HotsprSampleMSe3 OSB k141_53667
# 9.000001
# 76 Group_605
# 0 0 0.0
# 19 15 9.0
# 9.000001
# 77 Group_607
# 13 13 9.0
# 0 0 0.0
# Missing... HotsprSampleMS55 OSB k141_31054
# Missing... HotsprSampleMS60 OSB k141_35212
# Missing... HotsprSampleOSM3 OSB k141_24540
# 13.000001
# 78 Group_613
# 3 3 2.0
# 33 30 13.0
# Missing... Hotspr20Samplet1 OSB k141_20064
# Missing... Hotspr20SampleT9 OSA k141_5298
# Missing... Hotspr2Sample148 OSB k141_23442
# Missing... Hotspr2SamplePe2 OSA k141_11648
# Missing... HotsprottomLayer OSA k141_1010
# Missing... HotsprSampleMS55 OSB k141_18853
# Missing... HotsprSampleOSM2 OSA k141_8235
# Missing... HotsprSampleOSM2 OSB k141_12922
# 6.000001
# 79 Group_615
# 27 23 3.0
# 26 22 6.0
# Missing... Hotspr2Sample149 OSA k141_1670
# 5.000001
# 80 Group_62
# 24 23 4.0
# 19 19 5.0
# Missing... Hotspr20SampleP4 OSB k141_34469
# Missing... Hotspr2SamplePe2 OSB k141_41403
# Missing... HotsprSampleMS65 OSB k141_11648
# Missing... HotsprSampleMSe1 OSB k141_14202
# Missing... HotsprSampleMSe3 OSA k141_15562
# Missing... HotsprSampleOS55 OSB k141_6202
# Missing... HotsprSampleOSM4 OSA k141_20279
# Missing... HotsprSamplt10cd OSB k141_49750
# Missing... HotsprSampOS1260 OSB k141_6951
# Missing... HotsprSampOS1265 OSB k141_9196
# 4.000001
# 81 Group_627
# 10 8 4.0
# 14 6 2.0
# 13.000001
# 82 Group_629
# 0 0 0.0
# 18 18 13.0
# Missing... Hotspr20Samplet1 OSA k141_20341
# Missing... Hotspr20Samplet1 OSB k141_8248
# Missing... Hotspr20SampleT9 OSA k141_7937
# Missing... Hotspr2Sample148 OSA k141_10140
# Missing... Hotspr2Sample149 OSB k141_30404
# Missing... Hotspr2SamplePe2 OSA k141_6260
# Missing... Hotspr2SamplePe2 OSB k141_35266
# Missing... HotsprOSTMatCore OSA k141_390
# Missing... HotsprSampleMS50 OSA k141_10778
# Missing... HotsprSampleMS65 OSA k141_1741
# Missing... HotsprSampleOS60 OSB k141_12914
# Missing... HotsprSampleOS65 OSA k141_2432
# Missing... HotsprSampleOSM3 OSA k141_7355
# Missing... HotsprSampleOSM3 OSB k141_44387
# 11.000001
# 83 Group_634
# 23 14 6.0
# 23 18 11.0
# 6.000001
# 84 Group_636
# 11 11 6.0
# 0 0 0.0
# Missing... Hotspr2Sampleee2 OSB k141_10994
# Missing... HotsprSampleMS50 OSB k141_3044
# Missing... HotsprSampleMSe1 OSB k141_57471
# Missing... HotsprSampleOS65 OSB k141_40811
# 16.000001
# 85 Group_644
# 24 24 16.0
# 23 19 8.0
# Missing... Hotspr20Samplem2 OSB k141_282
# Missing... Hotspr20SampleP4 OSB k141_53117
# Missing... Hotspr20SampleT8 OSB k141_31834
# Missing... Hotspr20SampleT9 OSB k141_63094
# Missing... Hotspr2Sampleee2 OSB k141_50047
# Missing... Hotspr2SamplePe2 OSB k141_47213
# Missing... HotsprottomLayer OSA k141_470
# Missing... HotsprSampleMS60 OSB k141_38342
# Missing... HotsprSampleMSe1 OSB k141_24486
# Missing... HotsprSampleMSe3 OSB k141_49955
# Missing... HotsprSampleMSe4 OSB k141_3359
# Missing... HotsprSampleOS55 OSB k141_11642
# Missing... HotsprSampleOSM2 OSB k141_14714
# Missing... HotsprSampleOSM3 OSB k141_30236
# Missing... HotsprSampleOSM4 OSB k141_63907
# Missing... HotsprSampOS1265 OSB k141_10789
# 7.000001
# 86 Group_652
# 16 15 7.0
# 15 0 0.0
# Missing... Hotspr20Samplem2 OSA k141_20280
# 3.000001
# 87 Group_661
# 11 10 3.0
# 0 0 0.0
# Missing... HotsprSampleOSM4 OSB k141_21079
# 12.000001
# 88 Group_665
# 0 0 0.0
# 20 19 12.0
# Missing... Hotspr20Samplem2 OSB k141_20603
# Missing... Hotspr20SampleP4 OSA k141_22850
# Missing... Hotspr20SampleT8 OSA k141_5438
# Missing... Hotspr20SampleT8 OSB k141_16063
# Missing... Hotspr20SampleT8 OSB k141_6714
# Missing... Hotspr20SampleT9 OSA k141_21871
# Missing... Hotspr20SampleT9 OSB k141_7285
# Missing... Hotspr2Sampleee2 OSB k141_58364
# Missing... Hotspr2Sampleme2 OSA k141_21921
# Missing... Hotspr2Sampleme2 OSB k141_29427
# Missing... HotsprottomLayer_2 OSA k141_1437
# Missing... HotsprSampleMS13 OSA k141_22880
# Missing... HotsprSampleMS13 OSB k141_44539
# Missing... HotsprSampleMS60 OSB k141_29270
# Missing... HotsprSampleMSe1 OSA k141_3444
# Missing... HotsprSampleMSe1 OSB k141_36038
# Missing... HotsprSampleMSe2 OSA k141_12343
# Missing... HotsprSampleMSe2 OSB k141_6536
# Missing... HotsprSampleMSe3 OSA k141_19523
# Missing... HotsprSampleMSe3 OSB k141_28063
# Missing... HotsprSampleMSe4 OSB k141_67662
# Missing... HotsprSampleOS65 OSB k141_13501
# Missing... HotsprSamplt10cd OSB k141_12109
# Missing... HotsprSampOS1265 OSA k141_6197
# Missing... HotsprSampOS1265 OSB k141_2672
# 2.000001
# 89 Group_666
# 13 3 2.0
# 18 3 1.0
# Missing... Hotspr20SampleP4 OSA k141_17477
# Missing... HotsprOSTMatCore OSB k141_4362
# Missing... HotsprSampOS1265 OSB k141_1003
# 9.000001
# 90 Group_668
# 5 4 2.0
# 24 22 9.0
# Missing... Hotspr20Samplem2 OSA k141_14154
# Missing... HotsprSampleOS50 OSA k141_5617
# Missing... HotsprSampleOSM3 OSA k141_16519
# 4.000001
# 91 Group_685
# 19 16 4.0
# 8 8 3.0
# 5.000001
# 92 Group_688
# 12 12 5.0
# 0 0 0.0
# Missing... Hotspr20Samplem2 OSB k141_25303
# Missing... Hotspr20Samplet1 OSB k141_11911
# Missing... Hotspr2Sample148 OSB k141_400
# Missing... Hotspr2Sampleee2 OSB k141_73382
# Missing... Hotspr2Sampleme2 OSB k141_50838
# Missing... HotsprOSTMatCore OSB k141_7431
# Missing... HotsprottomLayer OSB k141_2326
# Missing... HotsprSampleMS13 OSB k141_30775
# Missing... HotsprSampleMS60 OSB k141_4043
# Missing... HotsprSampleMS65 OSB k141_11973
# Missing... HotsprSampleMSe1 OSB k141_32825
# Missing... HotsprSampleMSe2 OSB k141_26755
# Missing... HotsprSampleMSe3 OSB k141_32300
# Missing... HotsprSampleMSe4 OSB k141_78524
# Missing... HotsprSampleOS60 OSB k141_868
# Missing... HotsprSampleOSM1 OSB k141_8279
# Missing... HotsprSampleOSM2 OSB k141_9648
# Missing... HotsprSampleOSM3 OSB k141_30159
# Missing... HotsprSampleR4cd OSB k141_92357
# Missing... HotsprSampOS1260 OSB k141_6404
# Missing... HotsprSampOS1265 OSB k141_5812
# 7.000001
# 93 Group_692
# 0 0 0.0
# 29 8 7.0
# Missing... Hotspr2Sample148 OSA k141_11069
# Missing... Hotspr2SamplePe2 OSA k141_1269
# Missing... HotsprottomLayer_2 OSA k141_6531
# Missing... HotsprottomLayer OSA k141_2809
# Missing... HotsprSampleMS13 OSA k141_26575
# Missing... HotsprSampleMSe3 OSA k141_3604
# Missing... HotsprSampleOS50 OSA k141_11109
# Missing... HotsprSampleOSM1 OSB k141_9905
# Missing... HotsprSampleOSM2 OSA k141_7457
# Missing... HotsprSampleOSM2 OSB k141_12584
# Missing... HotsprSampOS1260 OSB k141_1993
# 22.000001
# 94 Group_695
# 23 15 7.0
# 41 38 22.0
# 4.000001
# 95 Group_700
# 19 19 4.0
# 5 5 2.0
# 5.000001
# 96 Group_723
# 21 21 5.0
# 9 9 3.0
# Missing... Hotspr20Samplet1 OSB k141_12113
# Missing... Hotspr2SamplePe2 OSA k141_13833
# Missing... HotsprSampleOSM2 OSB k141_5798
# Missing... HotsprSampleOSM3 OSA k141_712
# Missing... HotsprSampOS1260 OSB k141_17769
# 2.000001
# 97 Group_726
# 21 19 2.0
# 8 5 1.0
# Missing... HotsprSampOS1265 OSB k141_10565
# 4.000001
# 98 Group_728
# 9 9 4.0
# 8 7 4.0
# 2.000001
# 99 Group_730
# 8 8 2.0
# 4 4 1.0
# Missing... Hotspr2Sample149 OSA k141_9815
# 5.000001
# 100 Group_736
# 19 18 5.0
# 0 0 0.0
# 4.000001
# 101 Group_742
# 13 13 1.0
# 9 9 4.0
# Missing... Hotspr2Sampleme2 OSB k141_65611
# Missing... HotsprottomLayer_2 OSB k141_18339
# Missing... HotsprSampleOSM3 OSA k141_24040
# 5.000001
# 102 Group_746
# 3 2 1.0
# 35 33 5.0
# 2.000001
# 103 Group_749
# 12 12 2.0
# 2 2 1.0
# 2.000001
# 104 Group_768
# 8 8 2.0
# 2 2 1.0
# Missing... Hotspr2Sampleee2 OSA k141_29727
# Missing... HotsprSampleMS13 OSB k141_65026
# Missing... HotsprSampleMS65 OSA k141_5708
# Missing... HotsprSampleOSM4 OSA k141_21034
# Missing... HotsprSamplt10cd OSA k141_7778
# 12.000001
# 105 Group_774
# 21 17 12.0
# 16 15 10.0
# Missing... HotsprSampOS1260 OSB k141_10252
# 12.000001
# 106 Group_780
# 0 0 0.0
# 26 25 12.0
# Missing... Hotspr20Samplem2 OSB k141_22638
# Missing... Hotspr20SampleT9 OSA k141_21355
# Missing... Hotspr20SampleT9 OSB k141_59952
# Missing... Hotspr2Sample149 OSB k141_22920
# Missing... Hotspr2Sampleee2 OSA k141_5923
# Missing... Hotspr2Sampleee2 OSB k141_19048
# Missing... Hotspr2SamplePe2 OSA k141_5601
# Missing... Hotspr2SamplePe2 OSB k141_40737
# Missing... HotsprottomLayer OSA k141_1508
# Missing... HotsprottomLayer OSB k141_872
# Missing... HotsprSampleMS13 OSA k141_19748
# Missing... HotsprSampleMS13 OSB k141_6940
# Missing... HotsprSampleMS50 OSB k141_61496
# Missing... HotsprSampleMS65 OSA k141_10768
# Missing... HotsprSampleMS65 OSB k141_6531
# Missing... HotsprSampleMSe2 OSA k141_28541
# Missing... HotsprSampleMSe3 OSA k141_5859
# Missing... HotsprSampleMSe3 OSB k141_39859
# Missing... HotsprSampleOS55 OSA k141_22198
# Missing... HotsprSampleOS55 OSB k141_13037
# Missing... HotsprSampleOSM2 OSA k141_3555
# Missing... HotsprSampleOSM2 OSB k141_16273
# Missing... HotsprSampleOSM3 OSA k141_9011
# Missing... HotsprSampleOSM3 OSB k141_22256
# Missing... HotsprSamplt10cd OSB k141_15766
# Missing... HotsprSampOS1260 OSA k141_18077
# Missing... HotsprSampOS1260 OSB k141_16972
# Missing... HotsprSampOS1265 OSA k141_11621
# 1e-06
# 107 Group_786
# 13 0 0.0
# 15 0 0.0
# 4.000001
# 108 Group_797
# 11 11 4.0
# 0 0 0.0
# Missing... Hotspr20SampleT8 OSA k141_9074
# Missing... HotsprSampleMS55 OSA k141_7830
# Missing... HotsprSampleMSe1 OSA k141_15644
# Missing... HotsprSampleMSe2 OSA k141_5611
# 3.000001
# 109 Group_799
# 9 5 3.0
# 0 0 0.0
# Missing... Hotspr20Samplem2 OSA k141_8926
# 2.000001
# 110 Group_802
# 14 13 2.0
# 1 1 1.0
# Missing... Hotspr20Samplem2 OSB k141_10291
# Missing... Hotspr20Samplet1 OSB k141_12218
# Missing... HotsprSampleOS55 OSB k141_877
# Missing... HotsprSampleOS60 OSB k141_1069
# Missing... HotsprSampleOSM1 OSB k141_3835
# Missing... HotsprSampleOSM2 OSB k141_3862
# Missing... HotsprSampleOSM3 OSB k141_22208
# Missing... HotsprSampleOSM4 OSB k141_32405
# Missing... HotsprSamplt10cd OSB k141_40151
# Missing... HotsprSampOS1260 OSB k141_6072
# Missing... HotsprSampOS1265 OSB k141_2459
# 1e-06
# 111 Group_809
# 0 0 0.0
# 11 0 0.0
# Missing... Hotspr20Samplem2 OSB k141_12968
# Missing... Hotspr20SampleP4 OSA k141_12803
# Missing... Hotspr20SampleP4 OSB k141_11902
# Missing... Hotspr20SampleP4 OSB k141_2971
# Missing... Hotspr20Samplet1 OSA k141_8600
# Missing... Hotspr20Samplet1 OSB k141_2858
# Missing... Hotspr20SampleT8 OSA k141_18723
# Missing... Hotspr20SampleT8 OSB k141_16994
# Missing... Hotspr20SampleT9 OSA k141_11226
# Missing... Hotspr2Sample148 OSA k141_13018
# Missing... Hotspr2Sample148 OSB k141_9875
# Missing... Hotspr2Sample149 OSA k141_10767
# Missing... Hotspr2Sample149 OSB k141_16974
# Missing... Hotspr2Sampleee2 OSA k141_15649
# Missing... Hotspr2Sampleee2 OSB k141_33466
# Missing... Hotspr2Sampleme2 OSA k141_8439
# Missing... Hotspr2Sampleme2 OSB k141_9238
# Missing... Hotspr2SamplePe2 OSA k141_21557
# Missing... Hotspr2SamplePe2 OSB k141_20681
# Missing... HotsprottomLayer_2 OSB k141_12287
# Missing... HotsprottomLayer OSA k141_764
# Missing... HotsprottomLayer OSB k141_13354
# Missing... HotsprSampleMS13 OSA k141_20071
# Missing... HotsprSampleMS13 OSB k141_58843
# Missing... HotsprSampleMS50 OSA k141_1857
# Missing... HotsprSampleMS50 OSB k141_34680
# Missing... HotsprSampleMS60 OSA k141_17109
# Missing... HotsprSampleMS60 OSB k141_30596
# Missing... HotsprSampleMS65 OSB k141_1859
# Missing... HotsprSampleMSe1 OSA k141_26753
# Missing... HotsprSampleMSe1 OSB k141_35250
# Missing... HotsprSampleMSe2 OSA k141_11876
# Missing... HotsprSampleMSe2 OSB k141_87537
# Missing... HotsprSampleMSe3 OSA k141_6498
# Missing... HotsprSampleMSe3 OSB k141_1932
# Missing... HotsprSampleMSe4 OSA k141_16216
# Missing... HotsprSampleMSe4 OSB k141_73537
# Missing... HotsprSampleOS60 OSA k141_10347
# Missing... HotsprSampleOSM4 OSA k141_20401
# Missing... HotsprSampleOSM4 OSB k141_28119
# Missing... HotsprSampleR4cd OSA k141_32076
# Missing... HotsprSampleR4cd OSB k141_82955
# Missing... HotsprSamplt10cd OSA k141_11383
# Missing... HotsprSamplt10cd OSB k141_34971
# Missing... HotsprSampOS1265 OSA k141_3077
# Missing... HotsprSampOS1265 OSB k141_2585
# 1.000001
# 112 Group_835
# 22 0 0.0
# 25 1 1.0
# 2.000001
# 113 Group_844
# 12 12 2.0
# 4 4 2.0
# Missing... Hotspr2Sample149 OSB k141_10427
# Missing... HotsprSampleMS50 OSB k141_1386
# Missing... HotsprSampleMS55 OSA k141_8595
# 13.000001
# 114 Group_851
# 22 21 13.0
# 21 19 9.0
# Missing... Hotspr20Samplem2 OSA k141_19248
# Missing... HotsprottomLayer OSA k141_1937
# Missing... HotsprottomLayer OSA k141_5496
# Missing... HotsprSampleOSM1 OSB k141_13587
# Missing... HotsprSampleOSM2 OSB k141_954
# Missing... HotsprSampleOSM4 OSA k141_10938
# Missing... HotsprSampOS1260 OSB k141_2244
# 3.000001
# 115 Group_854
# 19 15 3.0
# 15 12 3.0
# Missing... HotsprOSTMatCore OSA k141_3782
# Missing... HotsprSampleOSM2 OSB k141_13212
# 1.000001
# 116 Group_856
# 6 5 1.0
# 2 1 1.0
# Missing... HotsprSampleOS65 OSA k141_1846
# 5.000001
# 117 Group_857
# 23 22 5.0
# 9 9 3.0
# Missing... Hotspr20SampleP4 OSA k141_28254
# Missing... Hotspr20SampleT8 OSA k141_13398
# Missing... Hotspr20SampleT9 OSA k141_8296
# Missing... Hotspr2Sample148 OSA k141_13923
# Missing... Hotspr2Sample149 OSA k141_11789
# Missing... Hotspr2Sampleee2 OSA k141_24948
# Missing... Hotspr2Sampleme2 OSA k141_21250
# Missing... Hotspr2SamplePe2 OSA k141_5863
# Missing... HotsprSampleMS13 OSA k141_10432
# Missing... HotsprSampleMS50 OSA k141_19879
# Missing... HotsprSampleMS55 OSA k141_14673
# Missing... HotsprSampleMS60 OSA k141_18629
# Missing... HotsprSampleMSe1 OSA k141_11683
# Missing... HotsprSampleMSe2 OSA k141_21959
# Missing... HotsprSampleMSe3 OSA k141_4094
# Missing... HotsprSampleMSe4 OSA k141_25157
# Missing... HotsprSampleOSM4 OSA k141_16823
# Missing... HotsprSampleR4cd OSA k141_16918
# Missing... HotsprSamplt10cd OSA k141_20937
# 1e-06
# 118 Group_861
# 19 0 0.0
# 0 0 0.0
# Missing... Hotspr20Samplet1 OSA k141_14401
# Missing... Hotspr20SampleT8 OSA k141_15431
# Missing... Hotspr2Sample148 OSA k141_12078
# Missing... Hotspr2Sample149 OSA k141_11372
# Missing... Hotspr2Sampleee2 OSA k141_164
# Missing... Hotspr2Sampleme2 OSA k141_19754
# Missing... HotsprSampleMS65 OSA k141_13565
# Missing... HotsprSampleOSM1 OSB k141_11474
# Missing... HotsprSampleOSM3 OSA k141_7517
# 2.000001
# 119 Group_873
# 12 4 1.0
# 8 7 2.0
# Missing... Hotspr2Sample148 OSB k141_478
# Missing... HotsprSampleOSM3 OSB k141_47929
# 12.000001
# 120 Group_878
# 2 2 2.0
# 19 17 12.0
# Missing... Hotspr20Samplem2 OSB k141_28583
# Missing... Hotspr2Sampleee2 OSB k141_29708
# Missing... Hotspr2Sampleme2 OSB k141_45152
# Missing... Hotspr2SamplePe2 OSB k141_42333
# Missing... HotsprSampleMS60 OSB k141_34993
# Missing... HotsprSampleMSe1 OSB k141_11897
# Missing... HotsprSampleMSe2 OSB k141_10302
# Missing... HotsprSampleOS60 OSB k141_4875
# Missing... HotsprSampleOSM2 OSB k141_12924
# 1.000001
# 121 Group_879
# 1 1 1.0
# 9 0 0.0
# Missing... Hotspr20SampleP4 OSA k141_6479
# Missing... Hotspr20SampleP4 OSB k141_30117
# Missing... Hotspr20SampleT8 OSA k141_8554
# Missing... Hotspr20SampleT8 OSB k141_59511
# Missing... Hotspr20SampleT9 OSA k141_9848
# Missing... Hotspr2Sample148 OSA k141_7100
# Missing... Hotspr2Sample148 OSB k141_39742
# Missing... Hotspr2Sampleee2 OSB k141_84093
# Missing... Hotspr2Sampleme2 OSB k141_44865
# Missing... HotsprSampleMS13 OSA k141_8552
# Missing... HotsprSampleMS13 OSB k141_17321
# Missing... HotsprSampleMSe1 OSA k141_16981
# Missing... HotsprSampleMSe1 OSB k141_40923
# Missing... HotsprSampleMSe2 OSB k141_24163
# Missing... HotsprSampleMSe3 OSA k141_1257
# Missing... HotsprSampleMSe3 OSB k141_2521
# Missing... HotsprSampleMSe4 OSA k141_5378
# Missing... HotsprSampleMSe4 OSB k141_27613
# Missing... HotsprSampleR4cd OSA k141_17242
# Missing... HotsprSampleR4cd OSB k141_90917
# Missing... HotsprSamplt10cd OSB k141_54444
# 1e-06
# 122 Group_886
# 9 0 0.0
# 12 0 0.0
# 1.000001
# 123 Group_888
# 7 7 1.0
# 0 0 0.0
# 15.000001
# 124 Group_904
# 0 0 0.0
# 26 26 15.0
# 19.000001
# 125 Group_915
# 0 0 0.0
# 28 28 19.0
# Missing... Hotspr2Sample148 OSB k141_33838
# Missing... HotsprSampleMS13 OSA k141_10853
# Missing... HotsprSampleMS60 OSA k141_15106
# Missing... HotsprSampleMS60 OSA k141_2492
# Missing... HotsprSampleMSe1 OSA k141_7287
# Missing... HotsprSampleMSe2 OSB k141_26697
# Missing... HotsprSampleMSe3 OSA k141_7380
# Missing... HotsprSampleMSe3 OSB k141_15105
# Missing... HotsprSampleMSe4 OSA k141_18756
# Missing... HotsprSampleOSM2 OSA k141_9466
# 14.000001
# 126 Group_920
# 17 10 5.0
# 22 19 14.0
# Missing... Hotspr2Sample148 OSB k141_5559
# Missing... HotsprSampleMS55 OSB k141_13567
# 12.000001
# 127 Group_928
# 0 0 0.0
# 20 18 12.0
# Missing... HotsprSampleOS50 OSB k141_27620
# Missing... HotsprSampleOSM4 OSB k141_23481
# 6.000001
# 128 Group_935
# 3 3 1.0
# 14 12 6.0
# 2.000001
# 129 Group_938
# 8 8 2.0
# 1 1 1.0
# 5.000001
# 130 Group_943
# 11 11 5.0
# 4 4 3.0
# 2.000001
# 131 Group_947
# 8 8 1.0
# 2 2 2.0
# 3.000001
# 132 Group_951
# 7 7 3.0
# 2 2 2.0
# Missing... Hotspr20SampleP4 OSA k141_14971
# Missing... Hotspr20SampleP4 OSB k141_33898
# Missing... Hotspr2Sampleee2 OSB k141_82297
# Missing... Hotspr2Sampleme2 OSA k141_19991
# Missing... HotsprSampleMS13 OSB k141_34760
# Missing... HotsprSampleMS60 OSA k141_1276
# Missing... HotsprSampleMSe2 OSA k141_3362
# Missing... HotsprSampleMSe2 OSB k141_60684
# Missing... HotsprSampleMSe4 OSB k141_33023
# Missing... HotsprSampleOS65 OSA k141_5210
# Missing... HotsprSampleOSM3 OSB k141_41997
# Missing... HotsprSampleOSM4 OSA k141_29582
# Missing... HotsprSamplt10cd OSA k141_12786
# 3.000001
# 133 Group_954
# 11 4 2.0
# 11 5 3.0
# Missing... Hotspr20SampleP4 OSA k141_20073
# Missing... Hotspr20SampleT8 OSA k141_606
# Missing... Hotspr2Sample148 OSA k141_12004
# Missing... Hotspr2Sampleee2 OSA k141_31649
# Missing... Hotspr2Sampleme2 OSA k141_22725
# Missing... HotsprSampleMS13 OSA k141_7989
# Missing... HotsprSampleMS50 OSA k141_315
# Missing... HotsprSampleMS55 OSA k141_1728
# Missing... HotsprSampleMS60 OSA k141_15812
# Missing... HotsprSampleMSe1 OSA k141_474
# Missing... HotsprSampleMSe3 OSA k141_12571
# Missing... HotsprSampleOSM3 OSA k141_1964
# 7.000001
# 134 Group_955
# 19 7 4.0
# 14 14 7.0
# Missing... HotsprSampleMS55 OSB k141_52647
# Missing... HotsprSampleOSM3 OSB k141_10684
# Missing... HotsprSampleOSM4 OSB k141_39385
# 3.000001
# 135 Group_961
# 0 0 0.0
# 11 8 3.0
# Missing... HotsprSampleOS55 OSB k141_10831
# Missing... HotsprSampOS1260 OSB k141_15226
# 5.000001
# 136 Group_963
# 1 1 1.0
# 8 6 5.0
# Missing... Hotspr20Samplem2 OSB k141_13394
# Missing... Hotspr20SampleP4 OSB k141_20312
# Missing... Hotspr20SampleT8 OSB k141_63292
# Missing... Hotspr20SampleT9 OSB k141_57808
# Missing... Hotspr2Sample148 OSB k141_36769
# Missing... Hotspr2Sample149 OSB k141_36228
# Missing... Hotspr2Sampleee2 OSB k141_48523
# Missing... Hotspr2Sampleme2 OSB k141_32139
# Missing... Hotspr2SamplePe2 OSB k141_6553
# Missing... HotsprottomLayer_2 OSB k141_12754
# Missing... HotsprottomLayer OSB k141_7796
# Missing... HotsprSampleMS13 OSB k141_11708
# Missing... HotsprSampleMS50 OSB k141_35894
# Missing... HotsprSampleMS55 OSB k141_45443
# Missing... HotsprSampleMS60 OSB k141_14779
# Missing... HotsprSampleMSe1 OSB k141_43363
# Missing... HotsprSampleMSe2 OSB k141_54990
# Missing... HotsprSampleMSe4 OSB k141_73788
# Missing... HotsprSampleOS50 OSB k141_11420
# Missing... HotsprSampleOS65 OSB k141_30933
# Missing... HotsprSampleOSM1 OSB k141_4282
# Missing... HotsprSampleOSM3 OSB k141_4178
# Missing... HotsprSampleOSM4 OSB k141_20380
# Missing... HotsprSampleR4cd OSB k141_23497
# Missing... HotsprSamplt10cd OSB k141_60612
# Missing... HotsprSampOS1260 OSB k141_2826
# Missing... HotsprSampOS1265 OSB k141_8253
# 1e-06
# 137 Group_967
# 0 0 0.0
# 27 0 0.0
# Missing... Hotspr20Samplem2 OSB k141_6207
# Missing... Hotspr20Samplet1 OSB k141_13198
# Missing... HotsprSampleMS65 OSB k141_4923
# Missing... HotsprSampleOSM1 OSB k141_6089
# Missing... HotsprSampleOSM2 OSB k141_8448
# Missing... HotsprSampleOSM4 OSB k141_46154
# Missing... HotsprSampOS1260 OSB k141_15924
# Missing... HotsprSampOS1265 OSB k141_165
# 1e-06
# 138 Group_970
# 0 0 0.0
# 8 0 0.0
# Missing... HotsprSampleMS55 OSB k141_21593
# 5.000001
# 139 Group_978
# 7 7 4.0
# 9 8 5.0
# Missing... Hotspr20Samplem2 OSA k141_6119
# Missing... Hotspr2Sampleme2 OSA k141_17602
# 4.000001
# 140 Group_980
# 19 17 4.0
# 3 3 2.0
# Missing... Hotspr20Samplem2 OSA k141_10429
# Missing... Hotspr20Samplet1 OSA k141_14215
# Missing... HotsprSampleMS65 OSB k141_7147
# Missing... HotsprSampleOS55 OSA k141_4086
# Missing... HotsprSamplt10cd OSA k141_4493
# Missing... HotsprSampOS1265 OSA k141_8584
# Missing... HotsprSampOS1265 OSB k141_5439
# 1e-06
# 141 Group_991
# 5 0 0.0
# 2 0 0.0

# %%
pdfs = listdir(out_dir)
pdfs.sort()
merger = PdfMerger()
for pdf in pdfs:
    if pdf.startswith('Group'):
        merger.append(out_dir+'/'+pdf)
        print(pdf)
# Out:
# Group_1003.pdf
# Group_1008.pdf
# Group_1012.pdf
# Group_1013.pdf
# Group_1015.pdf
# Group_1016.pdf
# Group_1021.pdf
# Group_1025.pdf
# Group_1030.pdf
# Group_1034.pdf
# Group_1040.pdf
# Group_1042.pdf
# Group_1044.pdf
# Group_105.pdf
# Group_1051.pdf
# Group_1058.pdf
# Group_1066.pdf
# Group_1075.pdf
# Group_1079.pdf
# Group_1098.pdf
# Group_1106.pdf
# Group_1153.pdf
# Group_1156.pdf
# Group_1174.pdf
# Group_1178.pdf
# Group_1184.pdf
# Group_1189.pdf
# Group_125.pdf
# Group_128.pdf
# Group_130.pdf
# Group_175.pdf
# Group_179.pdf
# Group_180.pdf
# Group_182.pdf
# Group_187.pdf
# Group_211.pdf
# Group_218.pdf
# Group_223.pdf
# Group_23.pdf
# Group_249.pdf
# Group_258.pdf
# Group_284.pdf
# Group_286.pdf
# Group_290.pdf
# Group_306.pdf
# Group_312.pdf
# Group_321.pdf
# Group_322.pdf
# Group_323.pdf
# Group_333.pdf
# Group_335.pdf
# Group_353.pdf
# Group_364.pdf
# Group_365.pdf
# Group_382.pdf
# Group_40.pdf
# Group_406.pdf
# Group_416.pdf
# Group_419.pdf
# Group_423.pdf
# Group_437.pdf
# Group_464.pdf
# Group_476.pdf
# Group_482.pdf
# Group_485.pdf
# Group_495.pdf
# Group_498.pdf
# Group_501.pdf
# Group_508.pdf
# Group_519.pdf
# Group_521.pdf
# Group_525.pdf
# Group_538.pdf
# Group_577.pdf
# Group_585.pdf
# Group_590.pdf
# Group_605.pdf
# Group_607.pdf
# Group_613.pdf
# Group_615.pdf
# Group_62.pdf
# Group_627.pdf
# Group_629.pdf
# Group_634.pdf
# Group_636.pdf
# Group_644.pdf
# Group_652.pdf
# Group_661.pdf
# Group_665.pdf
# Group_666.pdf
# Group_668.pdf
# Group_685.pdf
# Group_688.pdf
# Group_692.pdf
# Group_695.pdf
# Group_700.pdf
# Group_723.pdf
# Group_726.pdf
# Group_728.pdf
# Group_730.pdf
# Group_736.pdf
# Group_742.pdf
# Group_746.pdf
# Group_749.pdf
# Group_768.pdf
# Group_774.pdf
# Group_780.pdf
# Group_786.pdf
# Group_797.pdf
# Group_799.pdf
# Group_802.pdf
# Group_809.pdf
# Group_835.pdf
# Group_844.pdf
# Group_851.pdf
# Group_854.pdf
# Group_856.pdf
# Group_857.pdf
# Group_861.pdf
# Group_873.pdf
# Group_878.pdf
# Group_879.pdf
# Group_886.pdf
# Group_888.pdf
# Group_904.pdf
# Group_915.pdf
# Group_920.pdf
# Group_928.pdf
# Group_935.pdf
# Group_938.pdf
# Group_943.pdf
# Group_947.pdf
# Group_951.pdf
# Group_954.pdf
# Group_955.pdf
# Group_961.pdf
# Group_963.pdf
# Group_967.pdf
# Group_970.pdf
# Group_978.pdf
# Group_980.pdf
# Group_991.pdf

# %%
merger.write(out_dir+'/Circos.pdf')
merger.close()

# %%
d['Group_1021']
# Out:
# ['Hotspr20Samplem2_osb_k141_19542',
#  'Hotspr20SampleP4_osb_k141_16222',
#  'Hotspr20Samplet1_osb_k141_10031',
#  'Hotspr20SampleT8_osb_k141_63099',
#  'Hotspr20SampleT9_osb_k141_40430',
#  'Hotspr2Sample148_osb_k141_16155',
#  'Hotspr2Sample149_osb_k141_5083',
#  'Hotspr2Sampleee2_osb_k141_63386',
#  'Hotspr2Sampleme2_osb_k141_47137',
#  'Hotspr2SamplePe2_osb_k141_21553',
#  'HotsprottomLayer_2_osb_k141_7141',
#  'HotsprSampleMS13_osb_k141_67751',
#  'HotsprSampleMS50_osb_k141_19140',
#  'HotsprSampleMS55_osb_k141_25062',
#  'HotsprSampleMS60_osb_k141_37150',
#  'HotsprSampleMSe1_osb_k141_42547',
#  'HotsprSampleMSe3_osb_k141_34467',
#  'HotsprSampleMSe4_osb_k141_39229',
#  'HotsprSampleOS50_osb_k141_25763',
#  'HotsprSampleOS65_osb_k141_21149',
#  'HotsprSampleOSM2_osb_k141_7141',
#  'HotsprSampleOSM3_osb_k141_33276',
#  'HotsprSampleOSM4_osb_k141_64529',
#  'HotsprSampleR4cd_osb_k141_13282',
#  'HotsprSampOS1260_osb_k141_14707']

# %%
    df_novel_filtered[df_novel_filtered['GroupID']=='Group_1042']
# Out:
#                                Contig             RepresentativeContig  \
# 77    Hotspr20Samplem2_osb_k141_20839  Hotspr2Sampleee2_osb_k141_26365
# 231   Hotspr20SampleP4_osb_k141_41900  Hotspr2Sampleee2_osb_k141_26365
# 520   Hotspr20SampleT8_osb_k141_65461  Hotspr2Sampleee2_osb_k141_26365
# 625   Hotspr20SampleT9_osb_k141_26849  Hotspr2Sampleee2_osb_k141_26365
# 728   Hotspr2Sample148_osb_k141_13890  Hotspr2Sampleee2_osb_k141_26365
# 965   Hotspr2Sampleee2_osb_k141_26365  Hotspr2Sampleee2_osb_k141_26365
# 1127  Hotspr2Sampleme2_osb_k141_58968  Hotspr2Sampleee2_osb_k141_26365
# 1564  HotsprSampleMS13_osb_k141_67992  Hotspr2Sampleee2_osb_k141_26365
# 1631  HotsprSampleMS50_osb_k141_16957  Hotspr2Sampleee2_osb_k141_26365
# 1866   HotsprSampleMS60_osb_k141_1596  Hotspr2Sampleee2_osb_k141_26365
# 2110  HotsprSampleMSe1_osb_k141_39526  Hotspr2Sampleee2_osb_k141_26365
# 2429   HotsprSampleMSe3_osb_k141_6484  Hotspr2Sampleee2_osb_k141_26365
# 3066  HotsprSampleOSM3_osb_k141_23543  Hotspr2Sampleee2_osb_k141_26365
# 3183  HotsprSampleOSM4_osb_k141_14245  Hotspr2Sampleee2_osb_k141_26365
# 3330  HotsprSampleR4cd_osb_k141_19428  Hotspr2Sampleee2_osb_k141_26365
# 3443  HotsprSamplt10cd_osb_k141_15953  Hotspr2Sampleee2_osb_k141_26365
#
#          GroupID  RepresentativeContigLength  ContigLength  \
# 77    Group_1042                        1067           512
# 231   Group_1042                        1067           984
# 520   Group_1042                        1067          1061
# 625   Group_1042                        1067           855
# 728   Group_1042                        1067           821
# 965   Group_1042                        1067          1067
# 1127  Group_1042                        1067           893
# 1564  Group_1042                        1067           983
# 1631  Group_1042                        1067           932
# 1866  Group_1042                        1067           817
# 2110  Group_1042                        1067           806
# 2429  Group_1042                        1067           686
# 3066  Group_1042                        1067           565
# 3183  Group_1042                        1067           640
# 3330  Group_1042                        1067           932
# 3443  Group_1042                        1067           852
#
#      RepresentativeContigSynHits ContigSynHits MatchesToRef
# 77                           yes           yes          yes
# 231                          yes           yes          yes
# 520                          yes           yes          yes
# 625                          yes           yes          yes
# 728                          yes           yes          yes
# 965                          yes           yes          yes
# 1127                         yes           yes          yes
# 1564                         yes           yes          yes
# 1631                         yes           yes          yes
# 1866                         yes           yes          yes
# 2110                         yes           yes          yes
# 2429                         yes           yes          yes
# 3066                         yes           yes          yes
# 3183                         yes           yes          yes
# 3330                         yes           yes          yes
# 3443                         yes           yes          yes
